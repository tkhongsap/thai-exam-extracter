# %%
"""
This Python script extracts exam data from an API endpoint and saves the information as JSON files. 
The script loops through a range of exam IDs, fetches data including metadata (e.g., exam name, level, subject), 
questions, and choices, and saves the files in the "output" directory. 
The JSON files are named based on the exam metadata for easy identification.
"""

import requests
import json
import os
import re

# Function to sanitize filenames
def sanitize_filename(filename):
    # Replace invalid characters with an underscore
    return re.sub(r'[<>:"/\\|?*]', '_', filename)

# Loop through the range of exam IDs
for exam_id in range(12585, 13500):  # Adjust the range as needed
    # API endpoint URL
    api_url = f"https://www.trueplookpanya.com/webservice/api/examination/formdoexamination?exam_id={exam_id}"

    # Send a GET request to the API endpoint
    response = requests.get(api_url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the JSON response
        data = response.json()
        
        # Extract metadata
        metadata = {
            "exam_id": data['data']['exam']['exam_id'],
            "exam_name": data['data']['exam']['exam_name'],
            "level_name": data['data']['exam']['level_name'],
            "subject_name": data['data']['exam']['subject_name'],
            "question_count": data['data']['exam']['question_count']
        }
        
        # Create a filename based on metadata and sanitize it
        filename = f"{metadata['exam_id']}_{metadata['exam_name']}_{metadata['level_name']}_{metadata['subject_name']}.json"
        filename = sanitize_filename(filename)  # Sanitize the filename
        
        # Ensure the output directory exists
        output_dir = "output"
        os.makedirs(output_dir, exist_ok=True)
        
        # Full path for the output file
        file_path = os.path.join(output_dir, filename)
        
        # Extract questions and choices
        questions_list = []
        for i, question_data in enumerate(data['data']['formdo'], 1):
            question_detail = {
                "question_number": i,
                "question_id": question_data['question_id'],
                "question_text": question_data['question_detail'],
                "choices": []
            }
            
            for j, choice in enumerate(question_data['choice'], 1):
                choice_detail = {
                    "choice_number": j,
                    "choice_text": choice['detail'],
                    "is_correct": True if choice['answer'] == "true" else False
                }
                question_detail["choices"].append(choice_detail)
            
            questions_list.append(question_detail)
        
        # Combine metadata and questions into a single dictionary
        output_data = {
            "metadata": metadata,
            "questions": questions_list
        }
        
        # Save the result to a JSON file in the "output" folder
        with open(file_path, "w", encoding="utf-8") as json_file:
            json.dump(output_data, json_file, ensure_ascii=False, indent=4)

        print(f"Data extraction complete for exam_id {exam_id}. The data has been saved to '{file_path}'.")
    else:
        print(f"Failed to retrieve data for exam_id {exam_id}. Status code: {response.status_code}")
# Out:
# Data extraction complete for exam_id 12585. The data has been saved to 'output\12585_สิ่งต่างๆ รอบตัวเด็ก อ.1-อ.3 สีอะไรเอ่ย__ปฐมวัย_สิ่งต่าง ๆ รอบตัวเด็ก.json'.
# Data extraction complete for exam_id 12586. The data has been saved to 'output\12586_ภาษาไทย ป.1-ป.3 ข้อใดผิด_ประถมต้น_ภาษาไทย.json'.
# Failed to retrieve data for exam_id 12587. Status code: 201
# Failed to retrieve data for exam_id 12588. Status code: 201
# Data extraction complete for exam_id 12589. The data has been saved to 'output\12589_สิ่งต่างๆ รอบตัวเด็ก  อ.1 คณิตศาสตร์ของเด็กน้อย_อ.1_สิ่งต่าง ๆ รอบตัวเด็ก.json'.
# Failed to retrieve data for exam_id 12590. Status code: 201
# Failed to retrieve data for exam_id 12591. Status code: 201
# Failed to retrieve data for exam_id 12592. Status code: 201
# Failed to retrieve data for exam_id 12593. Status code: 201
# Failed to retrieve data for exam_id 12594. Status code: 201
# Failed to retrieve data for exam_id 12595. Status code: 201
# Failed to retrieve data for exam_id 12596. Status code: 201
# Data extraction complete for exam_id 12597. The data has been saved to 'output\12597_ภาษาอังกฤษ ป.5 The Free time on the weekend_ป.5_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12598. The data has been saved to 'output\12598_แบบฝึกหัด วิชาวิทยาศาสตร์ ป. 6 เรื่อง ดาราศาสตร์และอวกาศ ชุดที่ 4_ป.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Failed to retrieve data for exam_id 12599. Status code: 201
# Data extraction complete for exam_id 12600. The data has been saved to 'output\12600_ธรรมชาติรอบตัว อ.2 ความรู้ใกล้ตัว_อ.2_ธรรมชาติรอบตัว.json'.
# Data extraction complete for exam_id 12601. The data has been saved to 'output\12601_แบบฝึกหัด วิชาคณิตศาสตร์ ป. 1 เรื่อง การบวกและการลบ ชุดที่ 10_ป.1_คณิตศาสตร์.json'.
# Data extraction complete for exam_id 12602. The data has been saved to 'output\12602_คณิตศาสตร์ เรื่อง เรขาคณิต_ป.5_คณิตศาสตร์.json'.
# Failed to retrieve data for exam_id 12603. Status code: 201
# Failed to retrieve data for exam_id 12604. Status code: 201
# Failed to retrieve data for exam_id 12605. Status code: 201
# Data extraction complete for exam_id 12606. The data has been saved to 'output\12606_การงานอาชึพและเทคโนโลยี ป.5 หน่วยการเรียนรู้ที่ 1  เทคโนโลยีสารสนเทศเพื่อการสื่อสาร_ป.5_วิทยาศาสตร์และเทคโนโลยี.json'.
# Failed to retrieve data for exam_id 12607. Status code: 201
# Data extraction complete for exam_id 12608. The data has been saved to 'output\12608_ประวัติศาสตร์สุโขทัย_ม.6_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Failed to retrieve data for exam_id 12609. Status code: 201
# Data extraction complete for exam_id 12610. The data has been saved to 'output\12610_ภาษาอังกฤษ ป.3 คำศัพท์_ป.3_ภาษาต่างประเทศ.json'.
# Failed to retrieve data for exam_id 12611. Status code: 201
# Data extraction complete for exam_id 12612. The data has been saved to 'output\12612_สิ่งต่างๆ รอบตัวเด็ก อ.1 เลขง่ายๆ_อ.1_สิ่งต่าง ๆ รอบตัวเด็ก.json'.
# Failed to retrieve data for exam_id 12613. Status code: 201
# Failed to retrieve data for exam_id 12614. Status code: 201
# Failed to retrieve data for exam_id 12615. Status code: 201
# Data extraction complete for exam_id 12616. The data has been saved to 'output\12616_ภาษาอังกฤษ ม.1-ม.3 เรียนรู้คำศัพท์_มัธยมต้น_ภาษาต่างประเทศ.json'.
# Failed to retrieve data for exam_id 12617. Status code: 201
# Data extraction complete for exam_id 12618. The data has been saved to 'output\12618_แบบทดสอบ SMART-I วัดความสามารถด้านคณิตศาสตร์_ม.6_คณิตศาสตร์.json'.
# Data extraction complete for exam_id 12619. The data has been saved to 'output\12619_แบบทดสอบ SMART-I วัดความสามารถด้านการอ่าน_ม.6_ภาษาไทย.json'.
# Data extraction complete for exam_id 12620. The data has been saved to 'output\12620_แบบทดสอบ SMART-I วัดความสามารถด้านภาษาอังกฤษ_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12621. The data has been saved to 'output\12621_แบบทดสอบ SMART-I วัดความรู้รอบตัว_ม.6_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Data extraction complete for exam_id 12622. The data has been saved to 'output\12622_ข้อสอบ ภาษาไทย ชั้น ป. 5 เรื่อง สังข์ทอง_ป.5_ภาษาไทย.json'.
# Failed to retrieve data for exam_id 12623. Status code: 201
# Data extraction complete for exam_id 12624. The data has been saved to 'output\12624_การงานอาชึพและเทคโนโลยี ป.6 Photoshop cs5 เบื้องต้น_ป.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12625. The data has been saved to 'output\12625_การงานอาชึพและเทคโนโลยี ป.2 ข้อมูลและประโยชน์ของข้อมูล_ป.2_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12626. The data has been saved to 'output\12626_คณิตศาสตร์ เรื่อง สมการ ชุด 1_ป.6_คณิตศาสตร์.json'.
# Failed to retrieve data for exam_id 12627. Status code: 201
# Failed to retrieve data for exam_id 12628. Status code: 201
# Failed to retrieve data for exam_id 12629. Status code: 201
# Failed to retrieve data for exam_id 12630. Status code: 201
# Failed to retrieve data for exam_id 12631. Status code: 201
# Data extraction complete for exam_id 12632. The data has been saved to 'output\12632_แนวข้อสอบ PAT 5 ปี 2552 ชุดที่ 1_ม.6_PAT 5.json'.
# Data extraction complete for exam_id 12633. The data has been saved to 'output\12633_แนวข้อสอบ PAT 5 ปี 2552 ชุดที่ 2_ม.6_PAT 5.json'.
# Data extraction complete for exam_id 12634. The data has been saved to 'output\12634_แนวข้อสอบ PAT 5 ปี 2552 ชุดที่ 3_ม.6_PAT 5.json'.
# Failed to retrieve data for exam_id 12635. Status code: 201
# Data extraction complete for exam_id 12636. The data has been saved to 'output\12636_แนวข้อสอบ PAT 5 ปี 2552 ชุดที่ 4_ม.6_PAT 5.json'.
# Data extraction complete for exam_id 12637. The data has been saved to 'output\12637_แนวข้อสอบ PAT 5 ปี 2552 ชุดที่ 5_ม.6_PAT 5.json'.
# Failed to retrieve data for exam_id 12638. Status code: 201
# Failed to retrieve data for exam_id 12639. Status code: 201
# Data extraction complete for exam_id 12640. The data has been saved to 'output\12640_แบบฝึกหัด วิชาเคมี ม. 4 ชุดที่ 3_ม.4_วิทยาศาสตร์และเทคโนโลยี.json'.
# Failed to retrieve data for exam_id 12641. Status code: 201
# Failed to retrieve data for exam_id 12642. Status code: 201
# Failed to retrieve data for exam_id 12643. Status code: 201
# Data extraction complete for exam_id 12644. The data has been saved to 'output\12644_แบบฝึกหัด วิชาวิทยาศาสตร์ ป. 5 เรื่อง พืชและสัตว์น่ารู้_ป.5_วิทยาศาสตร์และเทคโนโลยี.json'.
# Failed to retrieve data for exam_id 12645. Status code: 201
# Failed to retrieve data for exam_id 12646. Status code: 201
# Failed to retrieve data for exam_id 12647. Status code: 201
# Failed to retrieve data for exam_id 12648. Status code: 201
# Failed to retrieve data for exam_id 12649. Status code: 201
# Failed to retrieve data for exam_id 12650. Status code: 201
# Failed to retrieve data for exam_id 12651. Status code: 201
# Failed to retrieve data for exam_id 12652. Status code: 201
# Failed to retrieve data for exam_id 12653. Status code: 201
# Failed to retrieve data for exam_id 12654. Status code: 201
# Data extraction complete for exam_id 12655. The data has been saved to 'output\12655_อเมริกาเหนือ ชุดที่1_ม.3_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Data extraction complete for exam_id 12656. The data has been saved to 'output\12656_อเมริกาเหนือ ชุดที่2_ม.3_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Failed to retrieve data for exam_id 12657. Status code: 201
# Data extraction complete for exam_id 12658. The data has been saved to 'output\12658_แนวข้อสอบ PAT 4 ปี 2552 ชุดที่ 1_ม.6_PAT 4.json'.
# Data extraction complete for exam_id 12659. The data has been saved to 'output\12659_แนวข้อสอบ PAT 4 ปี 2552 ชุดที่ 2_ม.6_PAT 4.json'.
# Data extraction complete for exam_id 12660. The data has been saved to 'output\12660_แนวข้อสอบ PAT 4 ปี 2553 ชุดที่ 1_ม.6_PAT 4.json'.
# Data extraction complete for exam_id 12661. The data has been saved to 'output\12661_แนวข้อสอบ PAT 4 ปี 2553 ชุดที่ 2_ม.6_PAT 4.json'.
# Data extraction complete for exam_id 12662. The data has been saved to 'output\12662_แนวข้อสอบ PAT 4 ปี 2553 ชุดที่ 3_ม.6_PAT 4.json'.
# Data extraction complete for exam_id 12663. The data has been saved to 'output\12663_แนวข้อสอบ PAT 4 ปี 2553 ชุดที่ 4_ม.6_PAT 4.json'.
# Failed to retrieve data for exam_id 12664. Status code: 201
# Failed to retrieve data for exam_id 12665. Status code: 201
# Failed to retrieve data for exam_id 12666. Status code: 201
# Failed to retrieve data for exam_id 12667. Status code: 201
# Failed to retrieve data for exam_id 12668. Status code: 201
# Data extraction complete for exam_id 12669. The data has been saved to 'output\12669_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2532) ชุดที่1_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12670. The data has been saved to 'output\12670_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2531) ชุดที่1_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12671. The data has been saved to 'output\12671_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2532) ชุดที่2_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12672. The data has been saved to 'output\12672_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2532) ชุดที่3_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12673. The data has been saved to 'output\12673_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2531) ชุดที่2_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12674. The data has been saved to 'output\12674_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2532) ชุดที่4_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12675. The data has been saved to 'output\12675_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2532) ชุดที่5_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12676. The data has been saved to 'output\12676_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2531) ชุดที่3_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12677. The data has been saved to 'output\12677_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2531) ชุดที่4_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12678. The data has been saved to 'output\12678_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2531) ชุดที่5_ม.6_ภาษาต่างประเทศ.json'.
# Failed to retrieve data for exam_id 12679. Status code: 201
# Data extraction complete for exam_id 12680. The data has been saved to 'output\12680_แบบฝึกหัด วิชาวิทยาศาสตร์ ม. 2 เรื่อง ระบบสืบพันธุ์_ม.2_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12681. The data has been saved to 'output\12681_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2532) ชุดที่6_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12682. The data has been saved to 'output\12682_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2533) ชุดที่1_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12683. The data has been saved to 'output\12683_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2533) ชุดที่2_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12684. The data has been saved to 'output\12684_แนวข้อสอบ A-level ม. 6 ภาษาไทย ชุดที่ 1_ม.6_ภาษาไทย.json'.
# Data extraction complete for exam_id 12685. The data has been saved to 'output\12685_แนวข้อสอบ A-level ม. 6 ภาษาไทย ชุดที่ 2_ม.6_ภาษาไทย.json'.
# Data extraction complete for exam_id 12686. The data has been saved to 'output\12686_แนวข้อสอบ A-level ม. 6 ภาษาไทย ชุดที่ 3_ม.6_ภาษาไทย.json'.
# Data extraction complete for exam_id 12687. The data has been saved to 'output\12687_แนวข้อสอบ A-level ม. 6 ภาษาไทย ชุดที่ 4_ม.6_ภาษาไทย.json'.
# Data extraction complete for exam_id 12688. The data has been saved to 'output\12688_แนวข้อสอบ A-level ม. 6 ภาษาไทย ชุดที่ 5_ม.6_ภาษาไทย.json'.
# Failed to retrieve data for exam_id 12689. Status code: 201
# Data extraction complete for exam_id 12690. The data has been saved to 'output\12690_แนวข้อสอบ O-NET ม. 6 ชีววิทยา ปี 2551 ชุดที่ 1_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12691. The data has been saved to 'output\12691_แนวข้อสอบ O-NET ม. 6 ชีววิทยา ปี 2550 ชุดที่ 2_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12692. The data has been saved to 'output\12692_แนวข้อสอบ O-NET ม. 6 ชีววิทยา ปี 2551 ชุดที่ 3_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12693. The data has been saved to 'output\12693_แนวข้อสอบ O-NET ม. 6 ภาษาไทย ปี 2552 ชุดที่ 1_ม.6_ภาษาไทย.json'.
# Data extraction complete for exam_id 12694. The data has been saved to 'output\12694_แนวข้อสอบ O-NET ม. 6 ภาษาไทย ปี 2552 ชุดที่ 2_ม.6_ภาษาไทย.json'.
# Data extraction complete for exam_id 12695. The data has been saved to 'output\12695_แบบฝึกหัด สังคมศึกษา ป. 4 เรื่อง การบริโภคสินค้าและบริการ_ป.4_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Data extraction complete for exam_id 12696. The data has been saved to 'output\12696_แบบฝึกหัด สังคมศึกษา ป. 4 เรื่อง เศรษฐกิจพอเพียง_ป.4_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Data extraction complete for exam_id 12697. The data has been saved to 'output\12697_แบบฝึกหัด สังคมศึกษา ป. 4 เรื่อง เงินทองของมีค่า_ป.4_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Failed to retrieve data for exam_id 12698. Status code: 201
# Failed to retrieve data for exam_id 12699. Status code: 201
# Failed to retrieve data for exam_id 12700. Status code: 201
# Data extraction complete for exam_id 12701. The data has been saved to 'output\12701_ข้อสอบ สังคมศึกษา ชั้น ป. 1 เรื่อง พุทธประวัติ_ป.1_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Failed to retrieve data for exam_id 12702. Status code: 201
# Failed to retrieve data for exam_id 12703. Status code: 201
# Data extraction complete for exam_id 12704. The data has been saved to 'output\12704_ข้อสอบศิลปะ ป.4 วรรณะสี_ป.4_ศิลปะ.json'.
# Data extraction complete for exam_id 12705. The data has been saved to 'output\12705_แนวข้อสอบ O-NET ม. 6 ภาษาไทย ปี 2552 ชุดที่ 3_ม.6_ภาษาไทย.json'.
# Data extraction complete for exam_id 12706. The data has been saved to 'output\12706_แนวข้อสอบ O-NET ม. 6 ภาษาไทย ปี 2552 ชุดที่ 4_ม.6_ภาษาไทย.json'.
# Data extraction complete for exam_id 12707. The data has been saved to 'output\12707_แนวข้อสอบ O-NET ม. 6 ภาษาไทย ปี 2552 ชุดที่ 5_ม.6_ภาษาไทย.json'.
# Data extraction complete for exam_id 12708. The data has been saved to 'output\12708_แนวข้อสอบ O-NET ม. 6 ภาษาไทย ปี 2553 ชุดที่ 1_ม.6_ภาษาไทย.json'.
# Data extraction complete for exam_id 12709. The data has been saved to 'output\12709_แนวข้อสอบ O-NET ม. 6 ภาษาไทย ปี 2553 ชุดที่ 2_ม.6_ภาษาไทย.json'.
# Data extraction complete for exam_id 12710. The data has been saved to 'output\12710_แนวข้อสอบ O-NET ม. 6 ภาษาไทย ปี 2553 ชุดที่ 3_ม.6_ภาษาไทย.json'.
# Data extraction complete for exam_id 12711. The data has been saved to 'output\12711_แนวข้อสอบ O-NET ม. 6 ภาษาไทย ปี 2553 ชุดที่ 4_ม.6_ภาษาไทย.json'.
# Failed to retrieve data for exam_id 12712. Status code: 201
# Data extraction complete for exam_id 12713. The data has been saved to 'output\12713_แนวข้อสอบ A-level ม. 6 สังคมศึกษา ชุดที่ 1_ม.6_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Data extraction complete for exam_id 12714. The data has been saved to 'output\12714_แนวข้อสอบ A-level ม. 6 สังคมศึกษา ชุดที่ 2_ม.6_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Data extraction complete for exam_id 12715. The data has been saved to 'output\12715_แนวข้อสอบ A-level ม. 6 สังคมศึกษา ชุดที่ 3_ม.6_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Data extraction complete for exam_id 12716. The data has been saved to 'output\12716_แนวข้อสอบ A-level ม. 6 สังคมศึกษา ชุดที่ 4_ม.6_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Data extraction complete for exam_id 12717. The data has been saved to 'output\12717_แนวข้อสอบ A-level ม. 6 สังคมศึกษา ชุดที่ 5_ม.6_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Data extraction complete for exam_id 12718. The data has been saved to 'output\12718_แนวข้อสอบ A-level ม. 6 สังคมศึกษา ชุดที่ 6_ม.6_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Data extraction complete for exam_id 12719. The data has been saved to 'output\12719_แนวข้อสอบ O-NET ม. 6 สังคมศึกษา ปี 2552 ชุดที่ 1_ม.6_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Data extraction complete for exam_id 12720. The data has been saved to 'output\12720_แนวข้อสอบ O-NET ม. 6 สังคมศึกษา ปี 2552 ชุดที่ 2_ม.6_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Data extraction complete for exam_id 12721. The data has been saved to 'output\12721_แนวข้อสอบ O-NET ม. 6 สังคมศึกษา ปี 2552 ชุดที่ 3_ม.6_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Data extraction complete for exam_id 12722. The data has been saved to 'output\12722_แนวข้อสอบ O-NET ม. 6 สังคมศึกษา ปี 2552 ชุดที่ 4_ม.6_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Data extraction complete for exam_id 12723. The data has been saved to 'output\12723_แนวข้อสอบ O-NET ม. 6 สังคมศึกษา ปี 2552 ชุดที่ 5_ม.6_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Data extraction complete for exam_id 12724. The data has been saved to 'output\12724_แนวข้อสอบ O-NET สังคมศึกษา(2553) ชุดที่1_ม.6_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Data extraction complete for exam_id 12725. The data has been saved to 'output\12725_แนวข้อสอบ O-NET ม. 6 สังคมศึกษา ปี 2553 ชุดที่ 2_ม.6_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Data extraction complete for exam_id 12726. The data has been saved to 'output\12726_แบบฝึกหัด วิชาวิทยาศาสตร์ ป. 6 เรื่อง ระบบย่อยอาหาร_ป.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12727. The data has been saved to 'output\12727_คณิตคิดไว_ปฐมวัย_คณิตศาสตร์.json'.
# Failed to retrieve data for exam_id 12728. Status code: 201
# Failed to retrieve data for exam_id 12729. Status code: 201
# Failed to retrieve data for exam_id 12730. Status code: 201
# Data extraction complete for exam_id 12731. The data has been saved to 'output\12731_แบบฝึกหัด วิชาวิทยาศาสตร์ ป. 4 เรื่อง ระบบสุริยะ ชุดที่ 6_ป.4_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12732. The data has been saved to 'output\12732_[Science] [EP1] ระบบสุริยะ_ประถมปลาย_วิทยาศาสตร์และเทคโนโลยี.json'.
# Failed to retrieve data for exam_id 12733. Status code: 201
# Failed to retrieve data for exam_id 12734. Status code: 201
# Failed to retrieve data for exam_id 12735. Status code: 201
# Failed to retrieve data for exam_id 12736. Status code: 201
# Failed to retrieve data for exam_id 12737. Status code: 201
# Failed to retrieve data for exam_id 12738. Status code: 201
# Data extraction complete for exam_id 12739. The data has been saved to 'output\12739_ระบบประสาทเเละต่อมไร้ท่อ_ม.1_สุขศึกษาและพลศึกษา.json'.
# Failed to retrieve data for exam_id 12740. Status code: 201
# Failed to retrieve data for exam_id 12741. Status code: 201
# Failed to retrieve data for exam_id 12742. Status code: 201
# Data extraction complete for exam_id 12743. The data has been saved to 'output\12743_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2531) ชุดที่6_ม.6_ภาษาต่างประเทศ.json'.
# Failed to retrieve data for exam_id 12744. Status code: 201
# Data extraction complete for exam_id 12745. The data has been saved to 'output\12745_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2533) ชุดที่3_ม.6_ภาษาต่างประเทศ.json'.
# Failed to retrieve data for exam_id 12746. Status code: 201
# Failed to retrieve data for exam_id 12747. Status code: 201
# Failed to retrieve data for exam_id 12748. Status code: 201
# Failed to retrieve data for exam_id 12749. Status code: 201
# Data extraction complete for exam_id 12750. The data has been saved to 'output\12750_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2533) ชุดที่4_ม.6_ภาษาต่างประเทศ.json'.
# Failed to retrieve data for exam_id 12751. Status code: 201
# Data extraction complete for exam_id 12752. The data has been saved to 'output\12752_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2533) ชุดที่5_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12753. The data has been saved to 'output\12753_คณิตศาสตร์ เรื่อง ร้อยละ_ป.5_คณิตศาสตร์.json'.
# Data extraction complete for exam_id 12754. The data has been saved to 'output\12754_บวกเลขง่ายๆ_ปฐมวัย_คณิตศาสตร์.json'.
# Failed to retrieve data for exam_id 12755. Status code: 201
# Data extraction complete for exam_id 12756. The data has been saved to 'output\12756_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2534) ชุดที่1_ม.6_ภาษาต่างประเทศ.json'.
# Failed to retrieve data for exam_id 12757. Status code: 201
# Data extraction complete for exam_id 12758. The data has been saved to 'output\12758_แนวข้อสอบ O-NET สุขศึกษาฯ ชุดที่1_ม.6_สุขศึกษาและพลศึกษา.json'.
# Data extraction complete for exam_id 12759. The data has been saved to 'output\12759_แนวข้อสอบ O-NET สุขศึกษาฯ ชุดที่2_ม.6_สุขศึกษาและพลศึกษา.json'.
# Data extraction complete for exam_id 12760. The data has been saved to 'output\12760_แนวข้อสอบ O-NET สุขศึกษาฯ ชุดที่3_ม.6_สุขศึกษาและพลศึกษา.json'.
# Failed to retrieve data for exam_id 12761. Status code: 201
# Failed to retrieve data for exam_id 12762. Status code: 201
# Failed to retrieve data for exam_id 12763. Status code: 201
# Data extraction complete for exam_id 12764. The data has been saved to 'output\12764_แบบฝึกหัดภาษาอังกฤษ ป. 1 คำศัพท์ ชุดที่ 1_ป.1_ภาษาต่างประเทศ.json'.
# Failed to retrieve data for exam_id 12765. Status code: 201
# Data extraction complete for exam_id 12766. The data has been saved to 'output\12766_ภาษาอังกฤษ ป.3 ตัวอักษรภาษาอังกฤษ_ป.3_ภาษาต่างประเทศ.json'.
# Failed to retrieve data for exam_id 12767. Status code: 201
# Data extraction complete for exam_id 12768. The data has been saved to 'output\12768_แนวข้อสอบ O-NET สุขศึกษาฯ(2552) ชุดที่1_ม.6_สุขศึกษาและพลศึกษา.json'.
# Failed to retrieve data for exam_id 12769. Status code: 201
# Data extraction complete for exam_id 12770. The data has been saved to 'output\12770_สิ่งต่างๆ รอบตัวเด็ก อ.1 คณิตศาสตร์_อ.1_สิ่งต่าง ๆ รอบตัวเด็ก.json'.
# Failed to retrieve data for exam_id 12771. Status code: 201
# Failed to retrieve data for exam_id 12772. Status code: 201
# Data extraction complete for exam_id 12773. The data has been saved to 'output\12773_ความรู้เกี่ยวกับตัวเด็ก อ.1 คณิตเก่งจัง_อ.1_ความรู้เกี่ยวกับตัวเด็ก.json'.
# Failed to retrieve data for exam_id 12774. Status code: 201
# Failed to retrieve data for exam_id 12775. Status code: 201
# Failed to retrieve data for exam_id 12776. Status code: 201
# Data extraction complete for exam_id 12777. The data has been saved to 'output\12777_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2534) ชุดที่2_ม.6_ภาษาต่างประเทศ.json'.
# Failed to retrieve data for exam_id 12778. Status code: 201
# Failed to retrieve data for exam_id 12779. Status code: 201
# Data extraction complete for exam_id 12780. The data has been saved to 'output\12780_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2534) ชุดที่3_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12781. The data has been saved to 'output\12781_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2534) ชุดที่4_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12782. The data has been saved to 'output\12782_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2534) ชุดที่5_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12783. The data has been saved to 'output\12783_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2534) ชุดที่6_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12784. The data has been saved to 'output\12784_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2535) ชุดที่1_ม.6_ภาษาต่างประเทศ.json'.
# Failed to retrieve data for exam_id 12785. Status code: 201
# Failed to retrieve data for exam_id 12786. Status code: 201
# Data extraction complete for exam_id 12787. The data has been saved to 'output\12787_แนวข้อสอบ O-NET สุขศึกษาฯ(2552) ชุดที่2_ม.6_สุขศึกษาและพลศึกษา.json'.
# Data extraction complete for exam_id 12788. The data has been saved to 'output\12788_แนวข้อสอบ O-NET สุขศึกษาฯ(2552) ชุดที่3_ม.6_สุขศึกษาและพลศึกษา.json'.
# Data extraction complete for exam_id 12789. The data has been saved to 'output\12789_แนวข้อสอบ O-NET สุขศึกษาฯ(2553) ชุดที่1_ม.6_สุขศึกษาและพลศึกษา.json'.
# Data extraction complete for exam_id 12790. The data has been saved to 'output\12790_แนวข้อสอบ O-NET สุขศึกษาฯ(2553) ชุดที่2_ม.6_สุขศึกษาและพลศึกษา.json'.
# Data extraction complete for exam_id 12791. The data has been saved to 'output\12791_แนวข้อสอบ O-NET ทัศนศิลป์ ชุดที่1_ม.6_ศิลปะ.json'.
# Data extraction complete for exam_id 12792. The data has been saved to 'output\12792_แนวข้อสอบ O-NET ทัศนศิลป์ ชุดที่2_ม.6_ศิลปะ.json'.
# Data extraction complete for exam_id 12793. The data has been saved to 'output\12793_แนวข้อสอบ O-NET ดนตรี ชุดที่1_ม.6_ศิลปะ.json'.
# Data extraction complete for exam_id 12794. The data has been saved to 'output\12794_แนวข้อสอบ O-NET ดนตรี ชุดที่2_ม.6_ศิลปะ.json'.
# Failed to retrieve data for exam_id 12795. Status code: 201
# Failed to retrieve data for exam_id 12796. Status code: 201
# Data extraction complete for exam_id 12797. The data has been saved to 'output\12797_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2535) ชุดที่2_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12798. The data has been saved to 'output\12798_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2535) ชุดที่3_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12799. The data has been saved to 'output\12799_แนวข้อสอบ O-NET ม. 6 สังคมศึกษา ปี 2553 ชุดที่ 3_ม.6_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Data extraction complete for exam_id 12800. The data has been saved to 'output\12800_แนวข้อสอบ O-NET ม. 6 สังคมศึกษา ปี 2553 ชุดที่ 4_ม.6_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Data extraction complete for exam_id 12801. The data has been saved to 'output\12801_แนวข้อสอบ O-NET ม. 6 สังคมศึกษา ปี 2553 ชุดที่ 5_ม.6_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Data extraction complete for exam_id 12802. The data has been saved to 'output\12802_แนวข้อสอบ O-NET นาฏศิลป์ ชุดที่1_ม.6_ศิลปะ.json'.
# Data extraction complete for exam_id 12803. The data has been saved to 'output\12803_แนวข้อสอบ O-NET นาฏศิลป์ ชุดที่2_ม.6_ศิลปะ.json'.
# Data extraction complete for exam_id 12804. The data has been saved to 'output\12804_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2535) ชุดที่4_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12805. The data has been saved to 'output\12805_แนวข้อสอบ O-NET วิชาศิลปะ(2552) ชุดที่1_ม.6_ศิลปะ.json'.
# Data extraction complete for exam_id 12806. The data has been saved to 'output\12806_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2535) ชุดที่5_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12807. The data has been saved to 'output\12807_แนวข้อสอบ O-NET วิชาศิลปะ(2552) ชุดที่2_ม.6_ศิลปะ.json'.
# Data extraction complete for exam_id 12808. The data has been saved to 'output\12808_ข้อสอบภาษาอังกฤษ ป.6 ชุดที่1_ป.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12809. The data has been saved to 'output\12809_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2535) ชุดที่6_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12810. The data has been saved to 'output\12810_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2536) ชุดที่1_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12811. The data has been saved to 'output\12811_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2536) ชุดที่2_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12812. The data has been saved to 'output\12812_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2536) ชุดที่3_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12813. The data has been saved to 'output\12813_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2536) ชุดที่4_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12814. The data has been saved to 'output\12814_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2536) ชุดที่5_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12815. The data has been saved to 'output\12815_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2536) ชุดที่6_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12816. The data has been saved to 'output\12816_แนวข้อสอบ O-NET วิชาศิลปะ(2553) ชุดที่1_ม.6_ศิลปะ.json'.
# Data extraction complete for exam_id 12817. The data has been saved to 'output\12817_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2537) ชุดที่1_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12818. The data has been saved to 'output\12818_แนวข้อสอบ O-NET วิชาศิลปะ(2553) ชุดที่2_ม.6_ศิลปะ.json'.
# Data extraction complete for exam_id 12819. The data has been saved to 'output\12819_แนวข้อสอบ O-NET วิชาการงานอาชีพและเทคโนโลยี ชุดที่1_ม.6_การงานอาชีพ.json'.
# Data extraction complete for exam_id 12820. The data has been saved to 'output\12820_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2537) ชุดที่2_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12821. The data has been saved to 'output\12821_แนวข้อสอบ O-NET วิชาการงานอาชีพและเทคโนโลยี ชุดที่2_ม.6_การงานอาชีพ.json'.
# Data extraction complete for exam_id 12822. The data has been saved to 'output\12822_แนวข้อสอบ O-NET วิชาการงานอาชีพและเทคโนโลยี ชุดที่3_ม.6_การงานอาชีพ.json'.
# Data extraction complete for exam_id 12823. The data has been saved to 'output\12823_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2537) ชุดที่3_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12824. The data has been saved to 'output\12824_แนวข้อสอบ O-NET วิชาการงานอาชีพและเทคโนโลยี ชุดที่4_ม.6_การงานอาชีพ.json'.
# Data extraction complete for exam_id 12825. The data has been saved to 'output\12825_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2537) ชุดที่4_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12826. The data has been saved to 'output\12826_แนวข้อสอบ O-NET วิชาการงานอาชีพและเทคโนโลยี ชุดที่5_ม.6_การงานอาชีพ.json'.
# Data extraction complete for exam_id 12827. The data has been saved to 'output\12827_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2537) ชุดที่5_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12828. The data has been saved to 'output\12828_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2537) ชุดที่6_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12829. The data has been saved to 'output\12829_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2538) ชุดที่1_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12830. The data has been saved to 'output\12830_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2538) ชุดที่2_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12831. The data has been saved to 'output\12831_แนวข้อสอบ O-NET ภาษาอังกฤษ(2551) ชุดที่1_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12832. The data has been saved to 'output\12832_แนวข้อสอบ O-NET ภาษาอังกฤษ(2551) ชุดที่2_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12833. The data has been saved to 'output\12833_แนวข้อสอบ O-NET ภาษาอังกฤษ(2551) ชุดที่3_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12834. The data has been saved to 'output\12834_แนวข้อสอบ O-NET วิชาการงานอาชีพและเทคโนโลยี(2552) ชุดที่1_ม.6_การงานอาชีพ.json'.
# Data extraction complete for exam_id 12835. The data has been saved to 'output\12835_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2538) ชุดที่3_ม.6_ภาษาต่างประเทศ.json'.
# Failed to retrieve data for exam_id 12836. Status code: 201
# Data extraction complete for exam_id 12837. The data has been saved to 'output\12837_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2538) ชุดที่4_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12838. The data has been saved to 'output\12838_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2538) ชุดที่5_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12839. The data has been saved to 'output\12839_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2538) ชุดที่6_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12840. The data has been saved to 'output\12840_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2539) ชุดที่1_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12841. The data has been saved to 'output\12841_แบบฝึกหัด วิชาวิทยาศาสตร์ ป. 4 เรื่อง แสงเคลื่อนที่จากแหล่งกำเนิด_ป.4_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12842. The data has been saved to 'output\12842_แบบฝึกหัด วิชาวิทยาศาสตร์ ป. 4 เรื่อง ระบบสุริยะ ชุดที่ 5_ป.4_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12843. The data has been saved to 'output\12843_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2539) ชุดที่2_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12844. The data has been saved to 'output\12844_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2539) ชุดที่3_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12845. The data has been saved to 'output\12845_แนวข้อสอบ O-NET วิชาการงานอาชีพและเทคโนโลยี(2552) ชุดที่2_ม.6_การงานอาชีพ.json'.
# Data extraction complete for exam_id 12846. The data has been saved to 'output\12846_แนวข้อสอบ O-NET วิชาการงานอาชีพและเทคโนโลยี(2553) ชุดที่1_ม.6_การงานอาชีพ.json'.
# Data extraction complete for exam_id 12847. The data has been saved to 'output\12847_แนวข้อสอบ O-NET วิชาการงานอาชีพและเทคโนโลยี(2553) ชุดที่2_ม.6_การงานอาชีพ.json'.
# Data extraction complete for exam_id 12848. The data has been saved to 'output\12848_แนวข้อสอบ O-NET ม. 6 ชีววิทยา ปี 2550 ชุดที่ 1_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12849. The data has been saved to 'output\12849_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2539) ชุดที่4_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12850. The data has been saved to 'output\12850_แนวข้อสอบ O-NET ชีววิทยา(2550) ชุดที่2_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12851. The data has been saved to 'output\12851_ข้อสอบวิชาคณิตศาสตร์ ป.5 เรื่องบวก ลบ คูณ หาร_ป.5_คณิตศาสตร์.json'.
# Failed to retrieve data for exam_id 12852. Status code: 201
# Data extraction complete for exam_id 12853. The data has been saved to 'output\12853_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2539) ชุดที่5_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12854. The data has been saved to 'output\12854_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2540) ชุดที่1_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12855. The data has been saved to 'output\12855_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2540) ชุดที่2_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12856. The data has been saved to 'output\12856_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2540) ชุดที่3_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12857. The data has been saved to 'output\12857_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2540) ชุดที่4_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12858. The data has been saved to 'output\12858_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2540) ชุดที่5_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12859. The data has been saved to 'output\12859_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2540) ชุดที่6_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12860. The data has been saved to 'output\12860_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2540) ชุดที่7_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12861. The data has been saved to 'output\12861_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2541) ชุดที่1_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12862. The data has been saved to 'output\12862_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2541) ชุดที่2_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12863. The data has been saved to 'output\12863_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2541) ชุดที่3_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12864. The data has been saved to 'output\12864_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2541) ชุดที่4_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12865. The data has been saved to 'output\12865_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2541) ชุดที่5_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12866. The data has been saved to 'output\12866_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2541) ชุดที่6_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12867. The data has been saved to 'output\12867_แนวข้อสอบ O-NET ม. 6 ฟิสิกส์ ปี 2550 ชุดที่ 1_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12868. The data has been saved to 'output\12868_แนวข้อสอบ O-NET ม. 6 เคมี ปี 2550_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12869. The data has been saved to 'output\12869_แนวข้อสอบ O-NET ม. 6 ฟิสิกส์ ปี 2550 ชุดที่ 2_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12870. The data has been saved to 'output\12870_แนวข้อสอบ O-NET ม. 6 เคมี ปี 2551 ชุดที่ 1_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12871. The data has been saved to 'output\12871_แนวข้อสอบ O-NET ม. 6 เคมี ปี 2551 ชุดที่ 2_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12872. The data has been saved to 'output\12872_แนวข้อสอบ O-NET ม. 6 ฟิสิกส์ ปี 2551 ชุดที่ 1_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12873. The data has been saved to 'output\12873_แนวข้อสอบ O-NET ม. 6 ฟิสิกส์ ปี 2551 ชุดที่ 2_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12874. The data has been saved to 'output\12874_แนวข้อสอบ A-level ม. 6 คณิตศาสตร์ ชุดที่ 1_ม.6_คณิตศาสตร์.json'.
# Data extraction complete for exam_id 12875. The data has been saved to 'output\12875_แนวข้อสอบ A-level ม. 6 คณิตศาสตร์ ชุดที่ 2_ม.6_คณิตศาสตร์.json'.
# Data extraction complete for exam_id 12876. The data has been saved to 'output\12876_แนวข้อสอบ A-level ม. 6 คณิตศาสตร์ ชุดที่ 3_ม.6_คณิตศาสตร์.json'.
# Data extraction complete for exam_id 12877. The data has been saved to 'output\12877_แนวข้อสอบ O-NET ม. 6 วิทยาศาสตร์ ชุดที่ 1_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12878. The data has been saved to 'output\12878_แนวข้อสอบ O-NET ม. 6 วิทยาศาสตร์ ชุดที่ 2_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12879. The data has been saved to 'output\12879_แนวข้อสอบ O-NET ม. 6 วิทยาศาสตร์ ชุดที่ 3_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12880. The data has been saved to 'output\12880_แนวข้อสอบ O-NET ม. 6 วิทยาศาสตร์ ชุดที่ 4_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12881. The data has been saved to 'output\12881_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2541) ชุดที่7_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12882. The data has been saved to 'output\12882_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2541) ชุดที่8_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12883. The data has been saved to 'output\12883_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2541) ชุดที่9_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12884. The data has been saved to 'output\12884_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2541) ชุดที่10_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12885. The data has been saved to 'output\12885_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2541) ชุดที่11_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12886. The data has been saved to 'output\12886_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2541) ชุดที่12_ม.6_ภาษาต่างประเทศ.json'.
# Failed to retrieve data for exam_id 12887. Status code: 201
# Data extraction complete for exam_id 12888. The data has been saved to 'output\12888_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2542) ชุดที่1_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12889. The data has been saved to 'output\12889_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2542) ชุดที่2_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12890. The data has been saved to 'output\12890_แนวข้อสอบ O-NET ม. 6 วิทยาศาสตร์ ชุดที่ 5_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12891. The data has been saved to 'output\12891_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2542) ชุดที่3_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12892. The data has been saved to 'output\12892_แนวข้อสอบ O-NET ม. 6 วิทยาศาสตร์ ชุดที่ 6_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12893. The data has been saved to 'output\12893_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2542) ชุดที่4_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12894. The data has been saved to 'output\12894_แนวข้อสอบ O-NET ม. 6 วิทยาศาสตร์ ปี 2552 ชุดที่ 5_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12895. The data has been saved to 'output\12895_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2542) ชุดที่5_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12896. The data has been saved to 'output\12896_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2542) ชุดที่6_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12897. The data has been saved to 'output\12897_แนวข้อสอบ O-NET ม. 6 วิทยาศาสตร์ ปี 2552 ชุดที่ 6_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12898. The data has been saved to 'output\12898_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2542) ชุดที่7_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12899. The data has been saved to 'output\12899_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2542) ชุดที่8_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12900. The data has been saved to 'output\12900_แนวข้อสอบ O-NET ม. 6 วิทยาศาสตร์ ปี 2552 ชุดที่ 7_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12901. The data has been saved to 'output\12901_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2542) ชุดที่9_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12902. The data has been saved to 'output\12902_แนวข้อสอบ O-NET ม. 6 วิทยาศาสตร์ ปี 2552 ชุดที่ 9_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12903. The data has been saved to 'output\12903_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2542) ชุดที่10_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12904. The data has been saved to 'output\12904_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2542) ชุดที่11_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12905. The data has been saved to 'output\12905_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2542) ชุดที่12_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12906. The data has been saved to 'output\12906_แนวข้อสอบ O-NET วิทยาศาสตร์(2552) ชุดที่9_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12907. The data has been saved to 'output\12907_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2543) ชุดที่1_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12908. The data has been saved to 'output\12908_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2543) ชุดที่2_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12909. The data has been saved to 'output\12909_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2543) ชุดที่3_ม.6_ภาษาต่างประเทศ.json'.
# Failed to retrieve data for exam_id 12910. Status code: 201
# Data extraction complete for exam_id 12911. The data has been saved to 'output\12911_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2543) ชุดที่4_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12912. The data has been saved to 'output\12912_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2543) ชุดที่5_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12913. The data has been saved to 'output\12913_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2543) ชุดที่6_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12914. The data has been saved to 'output\12914_แนวข้อสอบ O-NET ม. 6 วิทยาศาสตร์ ปี 2553 ชุดที่ 5_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12915. The data has been saved to 'output\12915_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2544) ชุดที่1_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12916. The data has been saved to 'output\12916_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2544) ชุดที่2_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12917. The data has been saved to 'output\12917_แนวข้อสอบ A-level ม. 6 คณิตศาสตร์ ชุดที่ 4_ม.6_คณิตศาสตร์.json'.
# Data extraction complete for exam_id 12918. The data has been saved to 'output\12918_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2544) ชุดที่3_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12919. The data has been saved to 'output\12919_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2544) ชุดที่4_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12920. The data has been saved to 'output\12920_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2544) ชุดที่5_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12921. The data has been saved to 'output\12921_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2544) ชุดที่6_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12922. The data has been saved to 'output\12922_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2544) ชุดที่7_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12923. The data has been saved to 'output\12923_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2545) ชุดที่1_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12924. The data has been saved to 'output\12924_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2545) ชุดที่2_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12925. The data has been saved to 'output\12925_แนวข้อสอบ O-NET ม. 6 วิทยาศาสตร์ ปี 2553 ชุดที่ 6_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12926. The data has been saved to 'output\12926_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2545) ชุดที่3_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12927. The data has been saved to 'output\12927_แนวข้อสอบ O-NET ม. 6 วิทยาศาสตร์ ปี 2553 ชุดที่ 7_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12928. The data has been saved to 'output\12928_แนวข้อสอบ O-NET ม. 6 วิทยาศาสตร์ ปี 2553 ชุดที่ 8_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12929. The data has been saved to 'output\12929_แนวข้อสอบ O-NET ม. 6 วิทยาศาสตร์ ปี 2553 ชุดที่ 9_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12930. The data has been saved to 'output\12930_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2545) ชุดที่4_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12931. The data has been saved to 'output\12931_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2545) ชุดที่5_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12932. The data has been saved to 'output\12932_แนวข้อสอบ O-NET ม. 6 วิทยาศาสตร์ ปี 2553 ชุดที่ 10_ม.6_วิทยาศาสตร์และเทคโนโลยี.json'.
# Data extraction complete for exam_id 12933. The data has been saved to 'output\12933_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2545) ชุดที่6_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12934. The data has been saved to 'output\12934_แนวข้อสอบ A-level ม. 6 ภาษาอังกฤษ ชุดที่ 1_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12935. The data has been saved to 'output\12935_แนวข้อสอบ A-level ม. 6 ภาษาอังกฤษ ชุดที่ 2_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12936. The data has been saved to 'output\12936_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2545) ชุดที่7_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12937. The data has been saved to 'output\12937_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2545) ชุดที่8_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12938. The data has been saved to 'output\12938_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2545) ชุดที่9_ม.6_ภาษาต่างประเทศ.json'.
# Failed to retrieve data for exam_id 12939. Status code: 201
# Data extraction complete for exam_id 12940. The data has been saved to 'output\12940_ข้อสอบ O-NET ม. 6 ภาษาอังกฤษ ปี 2551 ชุดที่ 1_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12941. The data has been saved to 'output\12941_ข้อสอบ O-NET ม. 6 ภาษาอังกฤษ ปี 2551 ชุดที่ 2_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12942. The data has been saved to 'output\12942_ข้อสอบ O-NET ม. 6 ภาษาอังกฤษ ปี 2551 ชุดที่ 3_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12943. The data has been saved to 'output\12943_ข้อสอบ O-NET ม. 6 ภาษาอังกฤษ ปี 2551 ชุดที่ 4_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12944. The data has been saved to 'output\12944_ข้อสอบ O-NET ม. 6 ภาษาอังกฤษ ปี 2551 ชุดที่ 5_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12945. The data has been saved to 'output\12945_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2545) ชุดที่10_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12946. The data has been saved to 'output\12946_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2545) ชุดที่11_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12947. The data has been saved to 'output\12947_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2545) ชุดที่12_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12948. The data has been saved to 'output\12948_ข้อสอบ O-NET ภาษาอังกฤษ ปี 2552 ชุดที่ 1_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12949. The data has been saved to 'output\12949_ข้อสอบเข้ามหาวิทยาลัย ภาษาอังกฤษ(2546) ชุดที่1_ม.6_ภาษาต่างประเทศ.json'.
# Data extraction complete for exam_id 12950. The data has been saved to 'output\12950_ข้อสอบ O-NET ภาษาอังกฤษ ปี 2552 ชุดที่ 2_ม.6_ภาษาต่างประเทศ.json'.
# ...
# Failed to retrieve data for exam_id 13380. Status code: 201
# Failed to retrieve data for exam_id 13381. Status code: 201
# Data extraction complete for exam_id 13382. The data has been saved to 'output\13382_ข้อสอบครูผู้ช่วย วิชาชีพครู ชุดที่ 1_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Failed to retrieve data for exam_id 13383. Status code: 201
# Data extraction complete for exam_id 13384. The data has been saved to 'output\13384_ข้อสอบครูผู้ช่วย วิชาภาษาไทย ชุดที่ 1_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Failed to retrieve data for exam_id 13385. Status code: 201
# Data extraction complete for exam_id 13386. The data has been saved to 'output\13386_ข้อสอบครูผู้ช่วย วิชาชีพครู ชุดที่ 2_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Failed to retrieve data for exam_id 13387. Status code: 201
# Failed to retrieve data for exam_id 13388. Status code: 201
# Data extraction complete for exam_id 13389. The data has been saved to 'output\13389_ข้อสอบครูผู้ช่วย วิชาภาษาไทย ชุดที่ 2_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13390. The data has been saved to 'output\13390_ข้อสอบครูผู้ช่วย วิชาชีพครู ชุดที่ 3_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13391. The data has been saved to 'output\13391_ข้อสอบครูผู้ช่วย วิชาชีพครู ชุดที่ 4_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13392. The data has been saved to 'output\13392_ข้อสอบครูผู้ช่วย วิชาภาษาไทย ชุดที่ 3_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13393. The data has been saved to 'output\13393_ข้อสอบครูผู้ช่วย วิชาภาษาไทย ชุดที่ 4_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13394. The data has been saved to 'output\13394_ข้อสอบครูผู้ช่วย วิชาชีพครู ชุดที่ 5_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13395. The data has been saved to 'output\13395_ข้อสอบครูผู้ช่วย วิชาชีพครู ชุดที่ 6_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13396. The data has been saved to 'output\13396_ข้อสอบครูผู้ช่วย วิชาชีพครู ชุดที่ 7_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13397. The data has been saved to 'output\13397_ข้อสอบครูผู้ช่วย วิชาภาษาไทย ชุดที่ 5_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Failed to retrieve data for exam_id 13398. Status code: 201
# Data extraction complete for exam_id 13399. The data has been saved to 'output\13399_ข้อสอบครูผู้ช่วย วิชาชีพครู ชุดที่ 8_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13400. The data has been saved to 'output\13400_ข้อสอบครูผู้ช่วย วิชาภาษาไทย ชุดที่ 6_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13401. The data has been saved to 'output\13401_ข้อสอบครูผู้ช่วย วิชาภาษาไทย ชุดที่ 7_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13402. The data has been saved to 'output\13402_ข้อสอบครูผู้ช่วย วิชาชีพครู ชุดที่ 9_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13403. The data has been saved to 'output\13403_ข้อสอบครูผู้ช่วย วิชาชีพครู ชุดที่ 10_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Failed to retrieve data for exam_id 13404. Status code: 201
# Failed to retrieve data for exam_id 13405. Status code: 201
# Data extraction complete for exam_id 13406. The data has been saved to 'output\13406_ข้อสอบครูผู้ช่วย วิชาชีพครู ชุดที่ 11_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Failed to retrieve data for exam_id 13407. Status code: 201
# Data extraction complete for exam_id 13408. The data has been saved to 'output\13408_ข้อสอบครูผู้ช่วย วิชาภาษาไทย ชุดที่ 8_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13409. The data has been saved to 'output\13409_ข้อสอบครูผู้ช่วย วิชาชีพครู ชุดที่ 12_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13410. The data has been saved to 'output\13410_ข้อสอบครูผู้ช่วย วิชาชีพครู ชุดที่ 13_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13411. The data has been saved to 'output\13411_ข้อสอบครูผู้ช่วย วิชาภาษาไทย ชุดที่ 9_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13412. The data has been saved to 'output\13412_ข้อสอบครูผู้ช่วย วิชาชีพครู ชุดที่ 14_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13413. The data has been saved to 'output\13413_ข้อสอบครูผู้ช่วย วิชาชีพครู ชุดที่ 15_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13414. The data has been saved to 'output\13414_ข้อสอบครูผู้ช่วย วิชาภาษาไทย ชุดที่ 10_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13415. The data has been saved to 'output\13415_ข้อสอบครูผู้ช่วย วิชาชีพครู ชุดที่ 16_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13416. The data has been saved to 'output\13416_ข้อสอบครูผู้ช่วย วิชาชีพครู ชุดที่ 17_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Failed to retrieve data for exam_id 13417. Status code: 201
# Data extraction complete for exam_id 13418. The data has been saved to 'output\13418_ข้อสอบครูผู้ช่วย วิชาชีพครู ชุดที่ 18_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13419. The data has been saved to 'output\13419_ข้อสอบครูผู้ช่วย วิชาภาษาไทย ชุดที่ 11_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13420. The data has been saved to 'output\13420_ข้อสอบครูผู้ช่วย วิชาชีพครู ชุดที่ 19_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13421. The data has been saved to 'output\13421_ข้อสอบครูผู้ช่วย วิชาภาษาไทย ชุดที่ 12_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13422. The data has been saved to 'output\13422_ข้อสอบครูผู้ช่วย วิชาชีพครู ชุดที่ 20_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13423. The data has been saved to 'output\13423_ข้อสอบครูผู้ช่วย วิชาภาษาไทย ชุดที่ 13_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13424. The data has been saved to 'output\13424_ข้อสอบครูผู้ช่วย วิชาชีพครู ชุดที่ 21_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13425. The data has been saved to 'output\13425_ข้อสอบครูผู้ช่วย วิชาภาษาไทย ชุดที่ 14_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13426. The data has been saved to 'output\13426_ข้อสอบครูผู้ช่วย วิชาภาษาไทย ชุดที่ 15_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13427. The data has been saved to 'output\13427_ข้อสอบครูผู้ช่วย วิชาภาษาไทย ชุดที่ 16_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13428. The data has been saved to 'output\13428_ข้อสอบครูผู้ช่วย วิชาภาษาไทย ชุดที่ 17_ไม่ระบุระดับชั้น_สอบบรรจุ.json'.
# Data extraction complete for exam_id 13429. The data has been saved to 'output\13429_แนวข้อสอบ ภาษาไทย ชั้น ป. 4 เรื่อง การสะกดคำ_ป.4_ภาษาไทย.json'.
# Data extraction complete for exam_id 13430. The data has been saved to 'output\13430_แนวข้อสอบ ภาษาไทย ชั้น ป. 4 เรื่อง มารยาทในการอ่าน_ป.4_ภาษาไทย.json'.
# Data extraction complete for exam_id 13431. The data has been saved to 'output\13431_แนวข้อสอบ ภาษาไทย ชั้น ป. 4 เรื่อง มาตราตัวสะกด_ป.4_ภาษาไทย.json'.
# Data extraction complete for exam_id 13432. The data has been saved to 'output\13432_แนวข้อสอบ ภาษาไทย ชั้น ป. 4 เรื่อง การผันวรรณยุกต์_ป.4_ภาษาไทย.json'.
# Data extraction complete for exam_id 13433. The data has been saved to 'output\13433_แนวข้อสอบ ภาษาไทย ชั้น ป. 4 เรื่อง มารยาทในการฟัง การดู และการพูด_ป.4_ภาษาไทย.json'.
# Data extraction complete for exam_id 13434. The data has been saved to 'output\13434_แนวข้อสอบ ภาษาไทย ชั้น ป. 4 เรื่อง เครื่องหมายวรรคตอน_ป.4_ภาษาไทย.json'.
# Failed to retrieve data for exam_id 13435. Status code: 201
# Failed to retrieve data for exam_id 13436. Status code: 201
# Failed to retrieve data for exam_id 13437. Status code: 201
# Data extraction complete for exam_id 13438. The data has been saved to 'output\13438_ข้อสอบ Post-Test  O-NET วิชาภาษาอังกฤษ ชั้นประถมศึกษาปีที่ 6 ชุดที่ 1_ป.6_O-NET.json'.
# Data extraction complete for exam_id 13439. The data has been saved to 'output\13439_ข้อสอบ Pre-Test O-NET วิชาภาษาอังกฤษ ชั้นประถมศึกษาปีที่ 6_ป.6_O-NET.json'.
# Data extraction complete for exam_id 13440. The data has been saved to 'output\13440_ข้อสอบ Post-Test  O-NET วิชาภาษาอังกฤษ ชั้นประถมศึกษาปีที่ 6 ชุดที่ 2_ป.6_O-NET.json'.
# Failed to retrieve data for exam_id 13441. Status code: 201
# Data extraction complete for exam_id 13442. The data has been saved to 'output\13442_ข้อสอบ _ เตรียมสอบเข้า ม. 1 วิชาภาษาอังกฤษ_ประถมปลาย_ภาษาต่างประเทศ.json'.
# Failed to retrieve data for exam_id 13443. Status code: 201
# Data extraction complete for exam_id 13444. The data has been saved to 'output\13444_CP-Meiji Tensai Pre-Test _ สังคมศึกษา สอบเข้า ม. 1_ประถมปลาย_สังคมศึกษา ศาสนา และวัฒนธรรม.json'.
# Failed to retrieve data for exam_id 13445. Status code: 201
# Failed to retrieve data for exam_id 13446. Status code: 201
# Data extraction complete for exam_id 13447. The data has been saved to 'output\13447_แนวข้อสอบ PAT 7.4 ความถนัดทางด้านภาษา จีน ชุดที่ 1_ม.6_PAT 7.4.json'.
# Data extraction complete for exam_id 13448. The data has been saved to 'output\13448_CP-Meiji Tensai Pre-Test _ คณิตศาสตร์ สอบเข้า ม. 1_ประถมปลาย_คณิตศาสตร์.json'.
# Failed to retrieve data for exam_id 13449. Status code: 201
# Data extraction complete for exam_id 13450. The data has been saved to 'output\13450_แนวข้อสอบ PAT 7.4 ความถนัดทางด้านภาษา จีน ชุดที่ 2_ม.6_PAT 7.4.json'.
# Data extraction complete for exam_id 13451. The data has been saved to 'output\13451_ข้อสอบ PAT 1 ความถนัดทางคณิตศาสตร์ มีนาคม 2553_ม.6_PAT 1.json'.
# Data extraction complete for exam_id 13452. The data has been saved to 'output\13452_แนวข้อสอบ PAT 1 ความถนัดทางคณิตศาสตร์ 2561 (ออกข้อสอบโดย WE BY THE BRAIN)_ม.6_PAT 1.json'.
# Data extraction complete for exam_id 13453. The data has been saved to 'output\13453_ข้อสอบ PAT 1 ความถนัดทางคณิตศาสตร์ มีนาคม 2554_ม.6_PAT 1.json'.
# Failed to retrieve data for exam_id 13454. Status code: 201
# Data extraction complete for exam_id 13455. The data has been saved to 'output\13455_แนวข้อสอบ PAT 2 ความถนัดทางวิทยาศาสตร์ 2561 (ออกข้อสอบโดย WE BY THE BRAIN)_ม.6_PAT 2.json'.
# Data extraction complete for exam_id 13456. The data has been saved to 'output\13456_ข้อสอบ PAT 2 ความถนัดทางวิทยาศาสตร์ มีนาคม 2553_ม.6_PAT 2.json'.
# Data extraction complete for exam_id 13457. The data has been saved to 'output\13457_ข้อสอบ PAT 2 ความถนัดทางวิทยาศาสตร์ มีนาคม 2554_ม.6_PAT 2.json'.
# Data extraction complete for exam_id 13458. The data has been saved to 'output\13458_แนวข้อสอบ PAT 5 ความถนัดทางวิชาชีพครู 2561_ม.6_PAT 5.json'.
# Data extraction complete for exam_id 13459. The data has been saved to 'output\13459_ข้อสอบ PAT 5 ความถนัดทางวิชาชีพครู ตุลาคม 2553_ม.6_PAT 5.json'.
# Data extraction complete for exam_id 13460. The data has been saved to 'output\13460_ข้อสอบ PAT 5 ความถนัดทางวิชาชีพครู มีนาคม 2554_ม.6_PAT 5.json'.
# Data extraction complete for exam_id 13461. The data has been saved to 'output\13461_แนวข้อสอบ GAT ภาษาอังกฤษ 2561_ม.6_GAT ภาษาอังกฤษ.json'.
# Data extraction complete for exam_id 13462. The data has been saved to 'output\13462_ข้อสอบ GAT  ภาษาอังกฤษ มีนาคม 2553_ม.6_GAT ภาษาอังกฤษ.json'.
# Data extraction complete for exam_id 13463. The data has been saved to 'output\13463_ข้อสอบ GAT  ภาษาอังกฤษ ตุลาคม 2553_ม.6_GAT ภาษาอังกฤษ.json'.
# Data extraction complete for exam_id 13464. The data has been saved to 'output\13464_ข้อสอบ O-NET ภาษาต่างประเทศ ป.6_ป.6_O-NET.json'.
# Data extraction complete for exam_id 13465. The data has been saved to 'output\13465_ข้อสอบ O-NET ภาษาต่างประเทศ ม.3_ม.3_O-NET.json'.
# Data extraction complete for exam_id 13466. The data has been saved to 'output\13466_ข้อสอบ O-NET ภาษาต่างประเทศ ม.6_ม.6_O-NET.json'.
# Data extraction complete for exam_id 13467. The data has been saved to 'output\13467_ข้อสอบ O-NET วิทยาศาสตร์ ป.6_ป.6_O-NET.json'.
# Data extraction complete for exam_id 13468. The data has been saved to 'output\13468_ข้อสอบ O-NET วิทยาศาสตร์ ม.3_ม.3_O-NET.json'.
# Data extraction complete for exam_id 13469. The data has been saved to 'output\13469_ข้อสอบ O-NET วิทยาศาสตร์ ม.6_ม.6_O-NET.json'.
# Data extraction complete for exam_id 13470. The data has been saved to 'output\13470_ข้อสอบ O-NET คณิตศาสตร์ ป.6_ป.6_O-NET.json'.
# Data extraction complete for exam_id 13471. The data has been saved to 'output\13471_ข้อสอบ O-NET คณิตศาสตร์ ม.3_ม.3_O-NET.json'.
# Data extraction complete for exam_id 13472. The data has been saved to 'output\13472_ข้อสอบ O-NET คณิตศาสตร์ ม.6_ม.6_O-NET.json'.
# Data extraction complete for exam_id 13473. The data has been saved to 'output\13473_ข้อสอบ O-NET ภาษาไทย ป.6_ป.6_O-NET.json'.
# Data extraction complete for exam_id 13474. The data has been saved to 'output\13474_ข้อสอบ O-NET ภาษาไทย ม.3_ม.3_O-NET.json'.
# Data extraction complete for exam_id 13475. The data has been saved to 'output\13475_ข้อสอบ O-NET ภาษาไทย ม.6_ม.6_O-NET.json'.
# Data extraction complete for exam_id 13476. The data has been saved to 'output\13476_ข้อสอบ O-NET สังคมศึกษา ศาสนาและวัฒนธรรม ป.6_ป.6_O-NET.json'.
# Data extraction complete for exam_id 13477. The data has been saved to 'output\13477_ข้อสอบ O-NET สังคมศึกษา ศาสนาและวัฒนธรรม ม.3_ม.3_O-NET.json'.
# Data extraction complete for exam_id 13478. The data has been saved to 'output\13478_ข้อสอบ O-NET สังคมศึกษา ศาสนาและวัฒนธรรม ม.6_ม.6_O-NET.json'.
# Data extraction complete for exam_id 13479. The data has been saved to 'output\13479_ข้อสอบ O-NET คณิตศาสตร์ ป.6 ปี58_ป.6_O-NET.json'.
# Data extraction complete for exam_id 13480. The data has been saved to 'output\13480_แนวข้อสอบ PAT 7.4 ความถนัดทางด้านภาษา จีน ชุดที่ 3_ม.6_PAT 7.json'.
# Data extraction complete for exam_id 13481. The data has been saved to 'output\13481_ข้อสอบ O-NET คณิตศาสตร์ ป.6 ปี53_ป.6_O-NET.json'.
# Data extraction complete for exam_id 13482. The data has been saved to 'output\13482_ข้อสอบ O-NET คณิตศาสตร์ ป.6 ปี59_ป.6_O-NET.json'.
# Data extraction complete for exam_id 13483. The data has been saved to 'output\13483_แนวข้อสอบวิทยาศาสตร์ O-NET ป. 6 ชุด 1_ป.6_O-NET.json'.
# Failed to retrieve data for exam_id 13484. Status code: 201
# Data extraction complete for exam_id 13485. The data has been saved to 'output\13485_แนวข้อสอบวิทยาศาสตร์ O-NET  ป. 6 ชุด 2_ป.6_O-NET.json'.
# Data extraction complete for exam_id 13486. The data has been saved to 'output\13486_แนวข้อสอบวิทยาศาสตร์ O-NET ป. 6 ชุด 3_ป.6_O-NET.json'.
# Data extraction complete for exam_id 13487. The data has been saved to 'output\13487_แนวข้อสอบวิทยาศาสตร์ O-NET ป. 6 ชุด 4_ป.6_O-NET.json'.
# Failed to retrieve data for exam_id 13488. Status code: 201
# Data extraction complete for exam_id 13489. The data has been saved to 'output\13489_แนวข้อสอบวิทยาศาสตร์ O-NET ป. 6 ชุด 5_ป.6_O-NET.json'.
# Data extraction complete for exam_id 13490. The data has been saved to 'output\13490_ข้อสอบ O-NET วิทยาศาสตร์ ม.3 ชุด 1_ม.3_O-NET.json'.
# Data extraction complete for exam_id 13491. The data has been saved to 'output\13491_ข้อสอบ O-NET วิทยาศาสตร์ ม.3 ชุด 2_ม.3_O-NET.json'.
# Failed to retrieve data for exam_id 13492. Status code: 201
# Data extraction complete for exam_id 13493. The data has been saved to 'output\13493_ข้อสอบ O-NET วิทยาศาสตร์ ม.3 ชุด 3_ม.3_O-NET.json'.
# Data extraction complete for exam_id 13494. The data has been saved to 'output\13494_ข้อสอบ O-NET วิทยาศาสตร์ ม.3 ชุด 4_ม.3_O-NET.json'.
# Data extraction complete for exam_id 13495. The data has been saved to 'output\13495_ข้อสอบ O-NET วิทยาศาสตร์ ม.3 ชุด 5_ม.3_O-NET.json'.
# Data extraction complete for exam_id 13496. The data has been saved to 'output\13496_แนวข้อสอบ A-level วิทยาศาสตร์ ม.6_ม.6_O-NET.json'.
# Data extraction complete for exam_id 13497. The data has been saved to 'output\13497_แนวข้อสอบ A-level คณิตศาสตร์ ม.6 ชุดที่ 7_ม.6_O-NET.json'.
# Data extraction complete for exam_id 13498. The data has been saved to 'output\13498_แนวข้อสอบ A-level ภาษาไทย ม. 6_ม.6_O-NET.json'.
# Data extraction complete for exam_id 13499. The data has been saved to 'output\13499_แนวข้อสอบ O-NET ภาษาต่างประเทศ ชั้น ม. 6_ม.6_O-NET.json'.
